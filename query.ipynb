# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\is\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests
from pprint import pprint

# %%
BASE_URL = "http://localhost:8000/api/productos/"

# %%
response = requests.get(BASE_URL)
print('Status:', response)
print('Status:', response.status_code)
try:
    print(response.json())
except Exception as e:
    print("No se pudo decodificar la respuesta como JSON. Respuesta cruda:")
    print(response.text)
# Out:
# Status: <Response [200]>
# Status: 200
# No se pudo decodificar la respuesta como JSON. Respuesta cruda:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Lista de Productos - Inventario</title>
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.3/dist/css/bootstrap.min.css" rel="stylesheet">
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0/css/all.min.css" rel="stylesheet">
#     <!-- Eliminada referencia a static/productos/style.css — estilos incorporados en <style> -->
#     <style>
#         .navbar-brand {
#             font-weight: bold;
#         }
#         .card {
#             box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#         }
#         .btn-delete {
#             background-color: #dc3545;
#             border-color: #dc3545;
#         }
#         .btn-delete:hover {
#             background-color: #c82333;
# ...

# %%
nuevo_producto = {
    "nombre": "Producto desde notebook",
    "descripcion": "Creado via Jupyter",
    "precio": 19.99,
}
response = requests.post(BASE_URL, data=nuevo_producto)
print('Status:', response.status_code)
try:
    print(response.json())
except Exception as e:
    print("No se pudo decodificar como JSON. Respuesta cruda:")
    print(response.text)
